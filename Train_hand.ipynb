# %%
import numpy as np 
import pandas as pd 
import os 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import data 
df = pd.read_csv("C:/KMUTNB/Project_own/python/Project/hand_sign_classification/dataset_hand.csv",index_col = False)
df.sample(10)
# Out:
#            X_0       Y_0       X_1       Y_1       X_2       Y_2       X_3  \
# 1052  0.255110  0.830530  0.461430  0.809147  0.642489  0.692301  0.754852
# 247   0.782684  0.803285  0.819248  0.628246  0.684931  0.420724  0.578046
# 764   0.265988  0.849949  0.476580  0.820168  0.651561  0.732221  0.779198
# 1092  0.281758  0.835933  0.470560  0.806338  0.642824  0.686799  0.749629
# 657   0.294429  0.796139  0.484854  0.781119  0.644415  0.708460  0.751598
# 986   0.278704  0.822343  0.472415  0.793045  0.641837  0.682188  0.746363
# 768   0.274831  0.844964  0.488215  0.815352  0.665709  0.730300  0.791491
# 835   0.292295  0.843319  0.490859  0.810748  0.651589  0.718811  0.774701
# 166   0.810269  0.737387  0.773490  0.560674  0.610993  0.381284  0.479447
# 992   0.277257  0.810698  0.467712  0.791969  0.642727  0.680476  0.746788
#
#            Y_3       X_4       Y_4  ...      Y_16      X_17      Y_17  \
# 1052  0.568314  0.855881  0.500625  ...  0.574508  0.210378  0.474088
# ...

# %%
# Check missing data
missing_data = df.isnull().sum()
print(missing_data)
df.info()
# Out:
# X_0      0
# Y_0      0
# X_1      0
# Y_1      0
# X_2      0
# Y_2      0
# X_3      0
# Y_3      0
# X_4      0
# Y_4      0
# X_5      0
# Y_5      0
# X_6      0
# Y_6      0
# X_7      0
# Y_7      0
# X_8      0
# Y_8      0
# X_9      0
# Y_9      0
# X_10     0
# Y_10     0
# X_11     0
# Y_11     0
# X_12     0
# Y_12     0
# X_13     0
# Y_13     0
# X_14     0
# Y_14     0
# X_15     0
# Y_15     0
# X_16     0
# Y_16     0
# X_17     0
# Y_17     0
# X_18     0
# Y_18     0
# X_19     0
# Y_19     0
# X_20     0
# Y_20     0
# Label    0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1505 entries, 0 to 1504
# Data columns (total 43 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X_0     1505 non-null   float64
#  1   Y_0     1505 non-null   float64
#  2   X_1     1505 non-null   float64
#  3   Y_1     1505 non-null   float64
#  4   X_2     1505 non-null   float64
#  5   Y_2     1505 non-null   float64
# ...

# %%
# Prepare data before train model
#import ast
#df["Landmark_Hand"] = df["Landmark_Hand"]
#df["Landmark_Hand"] = df["Landmark_Hand"].apply(lambda x: ast.literal_eval(x))

X = df.drop(["Label"],axis=1)

#X = np.asarray(df.drop(["Label"],axis=1))
y = df["Label"]
X
# Out:
#            X_0       Y_0       X_1       Y_1       X_2       Y_2       X_3  \
# 0     0.806679  0.780557  0.804999  0.597826  0.663066  0.396792  0.537669
# 1     0.805065  0.773556  0.802015  0.596905  0.656308  0.404338  0.533218
# 2     0.806179  0.778639  0.797370  0.592600  0.653145  0.397820  0.533523
# 3     0.791172  0.804925  0.831388  0.626491  0.706023  0.413008  0.598448
# 4     0.781778  0.812453  0.826525  0.635463  0.721443  0.414198  0.609732
# ...        ...       ...       ...       ...       ...       ...       ...
# 1500  0.391563  0.850573  0.574135  0.782322  0.695630  0.660801  0.768174
# 1501  0.395044  0.849404  0.572205  0.782069  0.690668  0.662255  0.762245
# 1502  0.360566  0.851829  0.553591  0.790355  0.680031  0.672925  0.756026
# 1503  0.365451  0.859877  0.554342  0.795695  0.681849  0.676648  0.761290
# 1504  0.370859  0.855094  0.560413  0.792373  0.689080  0.670810  0.764065
#
# ...

# %%
# Split data 

from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state = 47,shuffle=True)

print(X_train.shape,X_test.shape)
print(y_train.shape,y_test.shape)
# Out:
# (1053, 42) (452, 42)
# (1053,) (452,)

# %%
# Train Models
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB


forest_model = RandomForestClassifier()
SVC_model = SVC(kernel="linear",probability=True)
bayes_model = GaussianNB()

forest_model.fit(X_train,y_train)
SVC_model.fit(X_train,y_train)
bayes_model.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
# Evaluate model 
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

y_pred_forest = forest_model.predict(X_test)

acc_forest = accuracy_score(y_test,y_pred_forest)

print("Accuracy RD forest:{:.4f}".format(acc_forest))

class_report_forest = classification_report(y_test,y_pred_forest)
CF_matrix_forest = confusion_matrix(y_test,y_pred_forest)
print(class_report_forest)
print(CF_matrix_forest)
# Out:
# Accuracy RD forest:1.0000
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        97
#            1       1.00      1.00      1.00        86
#            2       1.00      1.00      1.00        95
#            3       1.00      1.00      1.00        94
#            4       1.00      1.00      1.00        80
#
#     accuracy                           1.00       452
#    macro avg       1.00      1.00      1.00       452
# weighted avg       1.00      1.00      1.00       452
#
# [[97  0  0  0  0]
#  [ 0 86  0  0  0]
#  [ 0  0 95  0  0]
#  [ 0  0  0 94  0]
#  [ 0  0  0  0 80]]

# %%
# Evaluate SVC model

y_pred_svc = SVC_model.predict(X_test)

acc_svc = accuracy_score(y_test,y_pred_svc)
print("Accuracy SVC: {:.4f}".format(acc_svc))

class_report_svc = classification_report(y_test,y_pred_svc)
CF_matrix_svc = confusion_matrix(y_test,y_pred_svc)
print(class_report_svc)
print(CF_matrix_svc)
# Out:
# Accuracy SVC: 1.0000
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        97
#            1       1.00      1.00      1.00        86
#            2       1.00      1.00      1.00        95
#            3       1.00      1.00      1.00        94
#            4       1.00      1.00      1.00        80
#
#     accuracy                           1.00       452
#    macro avg       1.00      1.00      1.00       452
# weighted avg       1.00      1.00      1.00       452
#
# [[97  0  0  0  0]
#  [ 0 86  0  0  0]
#  [ 0  0 95  0  0]
#  [ 0  0  0 94  0]
#  [ 0  0  0  0 80]]

# %%
# Evaluate NB model
y_pred_bayes = bayes_model.predict(X_test)

acc_bayes = accuracy_score(y_test,y_pred_bayes)
print("Accuracy NB: {:.4f}".format(acc_bayes))

class_report_bayes = classification_report(y_test,y_pred_bayes)
CF_mattrix_bayes = confusion_matrix(y_test,y_pred_bayes)
print(class_report_bayes)
print(CF_mattrix_bayes)
# Out:
# Accuracy NB: 0.9978
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        97
#            1       1.00      0.99      0.99        86
#            2       1.00      1.00      1.00        95
#            3       1.00      1.00      1.00        94
#            4       0.99      1.00      0.99        80
#
#     accuracy                           1.00       452
#    macro avg       1.00      1.00      1.00       452
# weighted avg       1.00      1.00      1.00       452
#
# [[97  0  0  0  0]
#  [ 0 85  0  0  1]
#  [ 0  0 95  0  0]
#  [ 0  0  0 94  0]
#  [ 0  0  0  0 80]]

# %%
# Save model 
import joblib

joblib.dump(forest_model,"forest_model.joblib")
# Out:
# ['forest_model.joblib']

# %%
# Save model 
import pickle 

#forest_model.save("C:/KMUTNB/Project_own/python/Project/hand_sign_classification/model_forest.h5")
f = open("/model_forest.pkl","wb")
pickle.dump(forest_model,f)
f.close()

# %%
df.columns
# Out:
# Index(['X_0', 'Y_0', 'X_1', 'Y_1', 'X_2', 'Y_2', 'X_3', 'Y_3', 'X_4', 'Y_4',
#        'X_5', 'Y_5', 'X_6', 'Y_6', 'X_7', 'Y_7', 'X_8', 'Y_8', 'X_9', 'Y_9',
#        'X_10', 'Y_10', 'X_11', 'Y_11', 'X_12', 'Y_12', 'X_13', 'Y_13', 'X_14',
#        'Y_14', 'X_15', 'Y_15', 'X_16', 'Y_16', 'X_17', 'Y_17', 'X_18', 'Y_18',
#        'X_19', 'Y_19', 'X_20', 'Y_20', 'Label'],
#       dtype='object')
